# %% [markdown]
# <a href="https://colab.research.google.com/github/Raziel-JKM/Python/blob/python/%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EC%9D%84%20%EC%9C%84%ED%95%9C%20%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC%2005%20Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()
x = np.arange(15) #0~14
y = x**2

ax.plot(
    x,y,
    linestyle=":",
    marker="*",
    color="#524FA1" #RGB 16진수
)

# %%
# line style

x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(x,x, linestyle = "-")
ax.plot(x,x+2, linestyle = "--")
ax.plot(x,x+4, linestyle = "-.")
ax.plot(x,x+6, linestyle = ":")

# %%
# line color
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(x,x, color="r")
ax.plot(x,x+2, color="green")
ax.plot(x,x+4, color="0.8")
ax.plot(x,x+6, color="#524FA1")

# %%
# line color
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(x,x, marker=".")
ax.plot(x,x+2, marker="o")
ax.plot(x,x+4, marker="v")
ax.plot(x,x+6, marker="s")
ax.plot(x,x+8, marker="*")

# %%
x = np.linspace(0, 10, 1000) # (start, end, step)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x))
ax.set_xlim(-2,12)  #lim 그래프 경계
ax.set_ylim(-1.5,1.5)  그래프 경계
# Out:
# (-1.5, 1.5)

# %%
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(x,x,label= 'y=x') # 일차식
ax.plot(x,x**2,label= 'y=x^2') #이차식
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend(loc='upper right', #범례 위치
          shadow=True,
          fancybox=True,
          borderpad=2) # 범례의 크기

# %% [markdown]
# ---

# %%
#from elice_utils import EliceUtils
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#elice_utils = EliceUtils()

#이미 입력되어 있는 코드의 다양한 속성값들을 변경해 봅시다.
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(
    x, x, label='y=x',
    linestyle=':',
    marker='o',
    color='blue'
)
ax.plot(
    x, x**2, label='y=x^2',
    linestyle='--',
    marker='^',
    color='red'
)

# elice에서 그래프를 확인
fig.savefig("plot.png")
#elice_utils.send_image("plot.png")

# %%
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(
    x, x, label='y=x',
    linestyle='-',# -
    marker='.', #.
    color='blue'
)
ax.plot(
    x, x**2, label='y=x^2',
    linestyle='-.',#-.
    marker=',', #,
    color='red'
)

# elice에서 그래프를 확인
fig.savefig("plot.png")
#elice_utils.send_image("plot.png")

# %%
# Line Styles
# 기호 | 의미
# -|-
# - | 실선
# – | 대시 선
# -. | 대시 점 선
# : | 점선

# Markers
# 기호 | 의미 | 기호 | 의미
# -|-|-|-
# . | 점 | , | 픽셀
# o | 원 | s | 사각형
# v, <, ^, > | 삼각형 | 1, 2, 3, 4 | 삼각선
# p | 사각형 | H, h | 육각형

# %%
#from elice_utils import EliceUtils
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#elice_utils = EliceUtils()

x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(
    x, x, label='y=x',
    linestyle='-',
    marker='.',
    color='blue'
)
ax.plot(
    x, x**2, label='y=x^2',
    linestyle='-.',
    marker=',',
    color='red'
)
ax.set_xlabel("x")
ax.set_ylabel("y")

#이미 입력되어 있는 코드의 다양한 속성값들을 변경해 봅시다.
ax.legend(
    loc='upper left',
    shadow=True,
    fancybox=True,
    borderpad=2
)

# elice에서 그래프를 확인
fig.savefig("plot.png")
#elice_utils.send_image("plot.png")

# %%
#범례의 위치를 왼쪽 중간으로 변경해보세요

x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(
    x, x, label='y=x',
    linestyle='-',
    marker='.',
    color='blue'
)
ax.plot(
    x, x**2, label='y=x^2',
    linestyle='-.',
    marker=',',
    color='red'
)
ax.set_xlabel("x")
ax.set_ylabel("y")

#이미 입력되어 있는 코드의 다양한 속성값들을 변경해 봅시다.
ax.legend(
    loc='center left', #center left = 6(같은 의미) # loc=6 가능
    shadow=True,
    fancybox=True,
    borderpad=2
)

# %%
# loc

# 문자형	code	문자형	code
# ‘best’	0	‘center left’	6
# ‘upper right’	1	‘center right’	7
# ‘upper left’	2	‘lower center’	8
# ‘lower left’	3	‘upper center’	9
# ‘lower right’	4	‘center’	10
# ‘right’	5	-	-

# %% [markdown]
# ---

# %%
#Bar plot

x = np.arange(10)
fig, ax = plt.subplots(figsize=(12,4))
ax.bar(x, x*2)
# Out:
# <BarContainer object of 10 artists>

# %%
x = np.random.rand(3) #  0~3까지 렌덤 추출 / 파랑x , 주황y, 녹색z 로 표현됨
y = np.random.rand(3)
z = np.random.rand(3)

data = [x,y,z]
fig, ax = plt.subplots()
x_ax = np.arange(3) #0,1,2가 포함, 3개의 기둥이 표현됨
for i in x_ax:
    ax.bar(x_ax, data[i], #data = [x,y,z]가 누적되게 구성
    bottom=np.sum(data[:i], axis=0)) # 쌓아올리는 시작점,data[:i] 누적의미, axis=0 세로로

# %%
x = np.random.rand(3)
y = np.random.rand(3)
z = np.random.rand(3)

data = [x,y,z]
fig, ax = plt.subplots()
x_ax = np.arange(3)
for i in x_ax:
    ax.bar(x_ax, data[i],
    bottom=np.sum(data[:i], axis=0))
#추가
    ax.set_xticks(x_ax) # x축이 0,1,2가 아니라 ABC로 명명해준다
    ax.set_xticklabels(["A","B","C"])

# %% [markdown]
# ---
#
# 도후분포표

# %%
#도수분포표(Histogram)

fig, ax = plt.subplots()
data = np.random.randn(1000) #천개 데이터 렌덤 
ax.hist(data, bins=50) # bins 막대를 의미 50개로 표현
# Out:
# (array([ 1.,  1.,  1.,  2.,  0.,  4.,  2.,  6.,  6.,  4.,  3., 10., 14.,
#         17., 21., 20., 30., 18., 25., 34., 32., 40., 33., 55., 52., 38.,
#         51., 44., 53., 46., 45., 42., 47., 27., 33., 26., 25., 22., 14.,
#         12., 15.,  8.,  4.,  4.,  2.,  3.,  2.,  4.,  1.,  1.]),
#  array([-3.09779723, -2.9778494 , -2.85790158, -2.73795375, -2.61800592,
#         -2.4980581 , -2.37811027, -2.25816244, -2.13821462, -2.01826679,
#         -1.89831897, -1.77837114, -1.65842331, -1.53847549, -1.41852766,
#         -1.29857983, -1.17863201, -1.05868418, -0.93873636, -0.81878853,
#         -0.6988407 , -0.57889288, -0.45894505, -0.33899722, -0.2190494 ,
#         -0.09910157,  0.02084626,  0.14079408,  0.26074191,  0.38068973,
#          0.50063756,  0.62058539,  0.74053321,  0.86048104,  0.98042887,
#          1.10037669,  1.22032452,  1.34027234,  1.46022017,  1.580168  ,
#          1.70011582,  1.82006365,  1.94001148,  2.0599593 ,  2.17990713,
# ...

# %% [markdown]
# ---

# %%
#from elice_utils import EliceUtils
#elice_utils = EliceUtils()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fname='./NanumBarunGothic.ttf'
#font = fm.FontProperties(fname = fname).get_name()
#plt.rcParams["font.family"] = font

# Data set
x = np.array(["축구", "야구", "농구", "배드민턴", "탁구"])
y = np.array([18, 7, 12, 10, 8])
z = np.random.randn(1000)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Bar 그래프
axes[0].bar(x, y)
# 히스토그램
axes[1].hist(z, bins = 50)


# elice에서 그래프 확인하기
fig.savefig("plot.png")
#elice_utils.send_image("plot.png")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# Data set
x = np.array(["축구", "야구", "농구", "배드민턴", "탁구"])
y = np.array([13,10,17,8,7]) #값변경
z = np.random.randn(1000)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Bar 그래프
axes[0].bar(x, y)
# 히스토그램
axes[1].hist(z, bins = 200)#값변경 200으로


# elice에서 그래프 확인하기
fig.savefig("plot.png")
#elice_utils.send_image("plot.png")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# #Matplotlib with pandas

# %%
df = pd.read_csv("./president_height.csv")
fig, ax = plt.subplots()
ax.plot(df["order"], df["height(cm)"], label="height")
ax.set_xlebel("order")
ax.set_ylabel("height(cm)")

# %% [markdown]
# ![Screen Shot 2021-07-22 at 11.33.55 PM.png](data:image/png;base64,...)

# %%
# and = &
# or = |

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [
#
# ```
# # 코드로 형식 지정됨](https://)
# ```
#
# ![image.png](data:image/png;base64,...)

# %%
#from elice_utils import EliceUtils
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#elice_utils = EliceUtils()

# 아래 경로에서 csv파일을 읽어서 df 변수에 저장해보세요.
# 경로: "./data/pokemon.csv"
df = None

# 공격 타입 Type 1, Type 2 중에 Fire 속성이 존재하는 데이터들만 추출해보세요.
fire = df
# 공격 타입 Type 1, Type 2 중에 Water 속성이 존재하는 데이터들만 추출해보세요.
water = df

fig, ax = plt.subplots()
# 왼쪽 표를 참고하여 아래 코드를 완성해보세요.
ax.scatter(fire['Attack'], fire['Defense'],
    marker='*', color=None, label=None, s=None)
ax.scatter(water['Attack'], water['Defense'],
    marker='.', color=None, label=None, s=None)

ax.set_xlabel("Attack")
ax.set_ylabel("Defense")
ax.legend(loc="upper right")

# elice에서 그래프 확인하기
fig.savefig("plot.png")
elice_utils.send_image("plot.png")

# %%
# 속성	fire	water
# x축	공격능력치	공격능력치
# y축	방어능력치	방어능력치
# 색상	빨강	파랑
# 라벨	Fire	Water
# 마커	*	.
# 크기	50	25

# %%
elice_utils = EliceUtils()

# 아래 경로에서 csv파일을 읽어서 df 변수에 저장해보세요.
# 경로: "./data/pokemon.csv"
df = pd.read_csv("./data/pokemon.csv")

# 공격 타입 Type 1, Type 2 중에 Fire 속성이 존재하는 데이터들만 추출해보세요.
fire = df[(df['Type 1']=='Fire')|(df['Type 2']=='Fire')]
# 공격 타입 Type 1, Type 2 중에 Water 속성이 존재하는 데이터들만 추출해보세요.
water = df[(df['Type 1']=='Water')|(df['Type 2']=='Water')]

fig, ax = plt.subplots()
# 왼쪽 표를 참고하여 아래 코드를 완성해보세요.
ax.scatter(fire['Attack'], fire['Defense'],
    marker='*', color='R', label='Fire', s=50)
ax.scatter(water['Attack'], water['Defense'],
    marker='.', color='B', label='Water', s=25)

ax.set_xlabel("Attack")
ax.set_ylabel("Defense")
ax.legend(loc="upper right")

# elice에서 그래프 확인하기
fig.savefig("plot.png")
elice_utils.send_image("plot.png")
